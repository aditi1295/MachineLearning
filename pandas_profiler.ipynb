# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi1295/MachineLearning/blob/main/pandas_profiler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/tested.csv')

# %%
# !pip uninstall -y pandas-profiling
# !pip install -U ydata-profiling
# Out:
# WARNING: Skipping pandas-profiling as it is not installed.
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df)
profile.to_file("output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
